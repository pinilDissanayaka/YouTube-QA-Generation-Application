# %% [markdown]
# <a href="https://colab.research.google.com/github/pinilDissanayaka/YouTube-QA-Generation-Application/blob/main/Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install youtube-transcript-api
# !pip install langchain
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2024.6.2)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.2
# Collecting langchain
#   Downloading langchain-0.2.6-py3-none-any.whl (975 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.10 (from langchain)
#   Downloading langchain_core-0.2.11-py3-none-any.whl (337 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 29.9 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.84-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.10->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.10->langchain) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.6 langchain-core-0.2.11 langchain-text-splitters-0.2.2 langsmith-0.1.84 orjson-3.10.6

# %%
videoUrl="https://www.youtube.com/watch?v=ZWUb_OiyGf8"

# %%
videoId=videoUrl.split("=")[-1]

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# retrieve the available transcripts
listTranscript=YouTubeTranscriptApi.list_transcripts(videoId)

# %%
transcript=[]
for i in listTranscript:
  transcript.append(i.fetch())

# %%
print(transcript)
print('='*100000)
print(transcript[0])
# Out:
# [[{'text': 'welcome fellow Learners today we are', 'start': 0.04, 'duration': 4.64}, {'text': 'diving into the word of Lang chain', 'start': 2.399, 'duration': 5.561}, {'text': 'agents focused specifically on SQL', 'start': 4.68, 'duration': 6.6}, {'text': 'agents we will be exploring how these', 'start': 7.96, 'duration': 6.4}, {'text': 'SQL agents can provide a more flexible', 'start': 11.28, 'duration': 5.919}, {'text': 'way to interact with SQL database when', 'start': 14.36, 'duration': 5.48}, {'text': 'compared to SQL chains throughout this', 'start': 17.199, 'duration': 6.041}, {'text': 'video we will not only uh explain these', 'start': 19.84, 'duration': 6.359}, {'text': 'Concepts clearly but also dive into the', 'start': 23.24, 'duration': 6.199}, {'text': 'code examples to see them in action so', 'start': 26.199, 'duration': 6.161}, {'text': "let's get started so let's first see the", 'start': 29.439, 'duration': 4.721}, {'text': 'agenda of this tutorial what we are', 'start': 32.36, 'duration': 5.6}, {'text': 'going to achieve so in this tutorial', 'start': 34.16, 'duration': 6.239}, {'text': 'first we are going to implement uh isql', 'start': 37.96, 'duration': 6.0}, {'text': 'chain so we will utilize a datab base', 'start': 40.399, 'duration': 5.721}, {'text': 'where there are number of tables present', 'start': 43.96, 'duration': 5.439}, {'text': 'in a single database so the size of the', 'start': 46.12, 'duration': 6.04}, {'text': 'tables in the database vary and also the', 'start': 49.399, 'duration': 4.281}, {'text': 'total number of tables would be around', 'start': 52.16, 'duration': 5.919}, {'text': '11 tables in the database and after this', 'start': 53.68, 'duration': 7.28}, {'text': 'uh after doing implementation of SQL', 'start': 58.079, 'duration': 6.8}, {'text': 'chains we will basically try to find out', 'start': 60.96, 'duration': 5.519}, {'text': 'what are their drawbacks what are their', 'start': 64.879, 'duration': 4.961}, {'text': 'limitations of these SQL chains and we', 'start': 66.479, 'duration': 6.0}, {'text': 'will look for the potential Solutions', 'start': 69.84, 'duration': 5.36}, {'text': 'and in the third and final step we will', 'start': 72.479, 'duration': 6.28}, {'text': 'basically introduce uh SQL agents and', 'start': 75.2, 'duration': 6.44}, {'text': 'look for how the how these basically SQL', 'start': 78.759, 'duration': 5.801}, {'text': 'agents solves the problem or limitations', 'start': 81.64, 'duration': 6.36}, {'text': 'that we have seen with the SQL uh chain', 'start': 84.56, 'duration': 6.519}, {'text': 'so this is quite our agenda that we are', 'start': 88.0, 'duration': 6.2}, {'text': 'going to follow in this', 'start': 91.079, 'duration': 6.601}, {'text': 'tutorial for either of SQL chain or SQL', 'start': 94.2, 'duration': 6.0}, {'text': 'agent there are primarily three major', 'start': 97.68, 'duration': 6.52}, {'text': 'steps the first step is to convert users', 'start': 100.2, 'duration': 6.84}, {'text': 'question or query into the esql query', 'start': 104.2, 'duration': 5.72}, {'text': 'the second step is to F the data from', 'start': 107.04, 'duration': 5.6}, {'text': 'SQL database by utilizing the generated', 'start': 109.92, 'duration': 5.32}, {'text': 'SQL query from the language model in the', 'start': 112.64, 'duration': 5.92}, {'text': 'third and final step it uses the F data', 'start': 115.24, 'duration': 6.239}, {'text': "from the SQL database and users's", 'start': 118.56, 'duration': 4.64}, {'text': 'question and pass it to the language', 'start': 121.479, 'duration': 4.68}, {'text': 'model and get the answer from it and', 'start': 123.2, 'duration': 6.679}, {'text': 'basically finally deliver it to the user', 'start': 126.159, 'duration': 7.481}, {'text': 'so to get get this done we are going to', 'start': 129.879, 'duration': 6.36}, {'text': 'follow a few steps in this notebook so', 'start': 133.64, 'duration': 5.28}, {'text': "let's first write do ...
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================ ...
# [{'text': 'welcome fellow Learners today we are', 'start': 0.04, 'duration': 4.64}, {'text': 'diving into the word of Lang chain', 'start': 2.399, 'duration': 5.561}, {'text': 'agents focused specifically on SQL', 'start': 4.68, 'duration': 6.6}, {'text': 'agents we will be exploring how these', 'start': 7.96, 'duration': 6.4}, {'text': 'SQL agents can provide a more flexible', 'start': 11.28, 'duration': 5.919}, {'text': 'way to interact with SQL database when', 'start': 14.36, 'duration': 5.48}, {'text': 'compared to SQL chains throughout this', 'start': 17.199, 'duration': 6.041}, {'text': 'video we will not only uh explain these', 'start': 19.84, 'duration': 6.359}, {'text': 'Concepts clearly but also dive into the', 'start': 23.24, 'duration': 6.199}, {'text': 'code examples to see them in action so', 'start': 26.199, 'duration': 6.161}, {'text': "let's get started so let's first see the", 'start': 29.439, 'duration': 4.721}, {'text': 'agenda of this tutorial what we are', 'start': 32.36, 'duration': 5.6}, {'text': 'going to achieve so in this tutorial', 'start': 34.16, 'duration': 6.239}, {'text': 'first we are going to implement uh isql', 'start': 37.96, 'duration': 6.0}, {'text': 'chain so we will utilize a datab base', 'start': 40.399, 'duration': 5.721}, {'text': 'where there are number of tables present', 'start': 43.96, 'duration': 5.439}, {'text': 'in a single database so the size of the', 'start': 46.12, 'duration': 6.04}, {'text': 'tables in the database vary and also the', 'start': 49.399, 'duration': 4.281}, {'text': 'total number of tables would be around', 'start': 52.16, 'duration': 5.919}, {'text': '11 tables in the database and after this', 'start': 53.68, 'duration': 7.28}, {'text': 'uh after doing implementation of SQL', 'start': 58.079, 'duration': 6.8}, {'text': 'chains we will basically try to find out', 'start': 60.96, 'duration': 5.519}, {'text': 'what are their drawbacks what are their', 'start': 64.879, 'duration': 4.961}, {'text': 'limitations of these SQL chains and we', 'start': 66.479, 'duration': 6.0}, {'text': 'will look for the potential Solutions', 'start': 69.84, 'duration': 5.36}, {'text': 'and in the third and final step we will', 'start': 72.479, 'duration': 6.28}, {'text': 'basically introduce uh SQL agents and', 'start': 75.2, 'duration': 6.44}, {'text': 'look for how the how these basically SQL', 'start': 78.759, 'duration': 5.801}, {'text': 'agents solves the problem or limitations', 'start': 81.64, 'duration': 6.36}, {'text': 'that we have seen with the SQL uh chain', 'start': 84.56, 'duration': 6.519}, {'text': 'so this is quite our agenda that we are', 'start': 88.0, 'duration': 6.2}, {'text': 'going to follow in this', 'start': 91.079, 'duration': 6.601}, {'text': 'tutorial for either of SQL chain or SQL', 'start': 94.2, 'duration': 6.0}, {'text': 'agent there are primarily three major', 'start': 97.68, 'duration': 6.52}, {'text': 'steps the first step is to convert users', 'start': 100.2, 'duration': 6.84}, {'text': 'question or query into the esql query', 'start': 104.2, 'duration': 5.72}, {'text': 'the second step is to F the data from', 'start': 107.04, 'duration': 5.6}, {'text': 'SQL database by utilizing the generated', 'start': 109.92, 'duration': 5.32}, {'text': 'SQL query from the language model in the', 'start': 112.64, 'duration': 5.92}, {'text': 'third and final step it uses the F data', 'start': 115.24, 'duration': 6.239}, {'text': "from the SQL database and users's", 'start': 118.56, 'duration': 4.64}, {'text': 'question and pass it to the language', 'start': 121.479, 'duration': 4.68}, {'text': 'model and get the answer from it and', 'start': 123.2, 'duration': 6.679}, {'text': 'basically finally deliver it to the user', 'start': 126.159, 'duration': 7.481}, {'text': 'so to get get this done we are going to', 'start': 129.879, 'duration': 6.36}, {'text': 'follow a few steps in this notebook so', 'start': 133.64, 'duration': 5.28}, {'text': "let's first write dow ...

# %%
text=[]
for chunk in transcript[0]:
  text.append(chunk['text'])

# %%
print(text)
# Out:
# ['welcome fellow Learners today we are', 'diving into the word of Lang chain', 'agents focused specifically on SQL', 'agents we will be exploring how these', 'SQL agents can provide a more flexible', 'way to interact with SQL database when', 'compared to SQL chains throughout this', 'video we will not only uh explain these', 'Concepts clearly but also dive into the', 'code examples to see them in action so', "let's get started so let's first see the", 'agenda of this tutorial what we are', 'going to achieve so in this tutorial', 'first we are going to implement uh isql', 'chain so we will utilize a datab base', 'where there are number of tables present', 'in a single database so the size of the', 'tables in the database vary and also the', 'total number of tables would be around', '11 tables in the database and after this', 'uh after doing implementation of SQL', 'chains we will basically try to find out', 'what are their drawbacks what are their', 'limitations of these SQL chains and we', 'will look for the potential Solutions', 'and in the third and final step we will', 'basically introduce uh SQL agents and', 'look for how the how these basically SQL', 'agents solves the problem or limitations', 'that we have seen with the SQL uh chain', 'so this is quite our agenda that we are', 'going to follow in this', 'tutorial for either of SQL chain or SQL', 'agent there are primarily three major', 'steps the first step is to convert users', 'question or query into the esql query', 'the second step is to F the data from', 'SQL database by utilizing the generated', 'SQL query from the language model in the', 'third and final step it uses the F data', "from the SQL database and users's", 'question and pass it to the language', 'model and get the answer from it and', 'basically finally deliver it to the user', 'so to get get this done we are going to', 'follow a few steps in this notebook so', "let's first write down those step in the", 'first step we are going to import the', 'data so basically the data is uh chinuk', 'data chinuk SQL database in the second', 'step we are going to initialize a', 'language model uh which is basically gbt', '3.5 turbo model in the third step we', 'will initialize a esql database chain', 'using Lang chain and in the fourth and', 'final step we are going to create a SQL', 'agent using L chain and see how this SQL', 'agent is beneficial over chain when we', 'are interacting with the SQL database so', 'to import uh SQL database uh into our', 'this this uh notebook we are first going', 'to import two classes the first one is', 'connect from sqid 3 library and the', 'second one is SQL database from Lang', 'chain community. utilities so the first', 'one connect class we can use this uh to', 'run any SQL query and F the results uh', 'from this SQL database directly and this', 'SQL database uh class we are going to', 'utilize it to get the complete data', 'database and uh the schema of the', 'database and then you utilize this', 'database to pass it it into Lang chain', 'chains and L chain uh agents so we will', 'just run this cell and if you see in the', 'next cell I have used from U function', 'from SQL database uh to basically import', 'this chinuk uh. DB database and also', 'pass this sample rows in table info uh', 'argument to see and to make it clear how', 'many rows that we need to see in the', 'table info and in in the next line I', 'have just uh printed out how many total', 'tables are there using db. get usable', 'table names function and uh and see how', 'how what are the different tables that', 'are available in this database so if we', 'run this cell you we can see there are', 'total of 11 tables the table names are', 'like album artist customer those are the', 'different tables that we are having we', 'can also get the table schema and uh', 'three rows that uh are present in the', 'different different tables in this', 'database using this uh DV do table info', 'so if you see uh after running this ce ...

# %%
text=' '.join(text)

# %%
with open('transcript.txt','w') as file:
  file.write(text)
